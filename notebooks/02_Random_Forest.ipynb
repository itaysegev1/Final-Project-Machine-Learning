# %% [markdown]
# # Random Forest
#
# Bagged trees (200 estimators). The strongest predictor in the lineup.

# %% [markdown]
# ## 1. Run the training script
#
# `train_random_forest.py` trains the model on the Baseline and Advanced matrices and writes its metrics and plots to `results/random_forest/`.

# %%
import os, sys
from pathlib import Path

if Path.cwd().name == "notebooks":
    os.chdir(Path.cwd().parent)
if str(Path.cwd()) not in sys.path:
    sys.path.insert(0, str(Path.cwd()))

# %%
# %run train_random_forest.py
# Out:
# ========================================================================
#   TRAIN — Random Forest   (random_state = 42)
# ========================================================================
#
#   --- Baseline  (X_train: (14578, 678)) ---
#      Test Accuracy : 0.6041
#      Test F1-Score : 0.6565
#      Confusion Matrix:
#                        Pred:Miss  Pred:Hit
#         True:Miss          823       875   FP rate = 0.5153
#         True:Hit           568      1379   FN rate = 0.2917
#
#   --- Advanced  (X_train: (14578, 687)) ---
#      Test Accuracy : 0.6239
#      Test F1-Score : 0.6753
#      Confusion Matrix:
#                        Pred:Miss  Pred:Hit
#         True:Miss          848       850   FP rate = 0.5006
#         True:Hit           521      1426   FN rate = 0.2676
#
#   >> Δ (Advanced − Baseline):  Acc +0.0198  |  F1 +0.0188
#
#   Top 20 feature importances (Advanced):
#     1  0.0475   avg_words_per_step
#     2  0.0418   calories
#     3  0.0416   sodium
#     4  0.0396   num_ingredients
#     5  0.0362   fat
#     6  0.0342   protein
#     7  0.0271   num_steps
#     8  0.0096   bon appétit
#     9  0.0093   has_technical_execution
#    10  0.0086   has_flavor_development
#    11  0.0086   quick & easy
#    12  0.0083   has_low_and_slow_techniques
#    13  0.0075   summer
#    14  0.0073   has_high_heat_techniques
#    15  0.0073   gourmet
#    16  0.0069   winter
#    17  0.0067   has_prep_and_patience
#    18  0.0064   bake
#    19  0.0063   has_premium_ingredients
#    20  0.0062   vegetarian
#
#   Wrote results/random_forest/metrics.json

# %% [markdown]
# ## 2. Plots

# %%
from IPython.display import Image, display

for name in ["confusion_matrix.png", "roc_curve.png", "feature_importance.png"]:
    display(Image(filename=f"results/random_forest/{name}"))

# %% [markdown]
# ## 3. Metrics summary

# %%
from src import load_metrics

metrics = load_metrics("random_forest")
for ds, vals in metrics["datasets"].items():
    print(f"{ds:>9}:  accuracy={vals['accuracy']:.4f}  F1={vals['f1']:.4f}")
# Out:
#  Baseline:  accuracy=0.6041  F1=0.6565
#  Advanced:  accuracy=0.6239  F1=0.6753
