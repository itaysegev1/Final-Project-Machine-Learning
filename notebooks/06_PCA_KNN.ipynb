# %% [markdown]
# # PCA + KNN
#
# PCA (90% variance) followed by KNN (k=5).

# %% [markdown]
# ## 1. Run the training script
#
# `train_pca_knn.py` trains the model on the Baseline and Advanced matrices and writes its metrics and plots to `results/pca_knn/`.

# %%
import os, sys
from pathlib import Path

if Path.cwd().name == "notebooks":
    os.chdir(Path.cwd().parent)
if str(Path.cwd()) not in sys.path:
    sys.path.insert(0, str(Path.cwd()))

# %%
# %run train_pca_knn.py
# Out:
# ...
#   TRAIN — PCA(0.90) + KNN   (random_state = 42)
# ...
#
#   --- Baseline  (X_train: (14578, 678)) ---
#      Test Accuracy : 0.5147
#      Test F1-Score : 0.5565
#      Confusion Matrix:
#                        Pred:Miss  Pred:Hit
#         True:Miss          766       932   FP rate = 0.5489
#         True:Hit           837      1110   FN rate = 0.4299
#      PCA components retained for 90% variance : 1
#
#   --- Advanced  (X_train: (14578, 687)) ---
#      Test Accuracy : 0.5092
#      Test F1-Score : 0.5508
#      Confusion Matrix:
#                        Pred:Miss  Pred:Hit
#         True:Miss          759       939   FP rate = 0.5530
#         True:Hit           850      1097   FN rate = 0.4366
#      PCA components retained for 90% variance : 1
#
#   >> Δ (Advanced − Baseline):  Acc -0.0055  |  F1 -0.0057
#
#   Wrote results/pca_knn/metrics.json

# %% [markdown]
# ## 2. Plots

# %%
from IPython.display import Image, display

for name in ["confusion_matrix.png", "roc_curve.png"]:
    display(Image(filename=f"results/pca_knn/{name}"))

# %% [markdown]
# ## 3. Metrics summary

# %%
from src import load_metrics

metrics = load_metrics("pca_knn")
for ds, vals in metrics["datasets"].items():
    print(f"{ds:>9}:  accuracy={vals['accuracy']:.4f}  F1={vals['f1']:.4f}")
# Out:
#  Baseline:  accuracy=0.5147  F1=0.5565
#  Advanced:  accuracy=0.5092  F1=0.5508
