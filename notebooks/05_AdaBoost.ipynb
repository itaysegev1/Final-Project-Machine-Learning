# %% [markdown]
# # AdaBoost
#
# Boosted decision stumps (100 estimators).

# %% [markdown]
# ## 1. Run the training script
#
# `train_adaboost.py` trains the model on the Baseline and Advanced matrices and writes its metrics and plots to `results/adaboost/`.

# %%
import os, sys
from pathlib import Path

if Path.cwd().name == "notebooks":
    os.chdir(Path.cwd().parent)
if str(Path.cwd()) not in sys.path:
    sys.path.insert(0, str(Path.cwd()))

# %%
# %run train_adaboost.py
# Out:
# ...
#   TRAIN — AdaBoost (n=100)   (random_state = 42)
# ...
#
#   --- Baseline  (X_train: (14578, 678)) ---
#      Test Accuracy : 0.5948
#      Test F1-Score : 0.6621
#      Confusion Matrix:
#                        Pred:Miss  Pred:Hit
#         True:Miss          721       977   FP rate = 0.5754
#         True:Hit           500      1447   FN rate = 0.2568
#
#   --- Advanced  (X_train: (14578, 687)) ---
#      Test Accuracy : 0.5967
#      Test F1-Score : 0.6518
#      Confusion Matrix:
#                        Pred:Miss  Pred:Hit
#         True:Miss          799       899   FP rate = 0.5294
#         True:Hit           571      1376   FN rate = 0.2933
#
#   >> Δ (Advanced − Baseline):  Acc +0.0019  |  F1 -0.0103
#
#   Wrote results/adaboost/metrics.json

# %% [markdown]
# ## 2. Plots

# %%
from IPython.display import Image, display

for name in ["confusion_matrix.png", "roc_curve.png"]:
    display(Image(filename=f"results/adaboost/{name}"))

# %% [markdown]
# ## 3. Metrics summary

# %%
from src import load_metrics

metrics = load_metrics("adaboost")
for ds, vals in metrics["datasets"].items():
    print(f"{ds:>9}:  accuracy={vals['accuracy']:.4f}  F1={vals['f1']:.4f}")
# Out:
#  Baseline:  accuracy=0.5948  F1=0.6621
#  Advanced:  accuracy=0.5967  F1=0.6518
