# %% [markdown]
# # Perceptron
#
# The simplest linear model, kept as a baseline floor.

# %% [markdown]
# ## 1. Run the training script
#
# `train_perceptron.py` trains the model on the Baseline and Advanced matrices and writes its metrics and plots to `results/perceptron/`.

# %%
import os, sys
from pathlib import Path

if Path.cwd().name == "notebooks":
    os.chdir(Path.cwd().parent)
if str(Path.cwd()) not in sys.path:
    sys.path.insert(0, str(Path.cwd()))

# %%
# %run train_perceptron.py
# Out:
# ...
#   TRAIN — Perceptron   (random_state = 42)
# ...
#
#   --- Baseline  (X_train: (14578, 678)) ---
#      Test Accuracy : 0.5495
#      Test F1-Score : 0.5726
#      Confusion Matrix:
#                        Pred:Miss  Pred:Hit
#         True:Miss          903       795   FP rate = 0.4682
#         True:Hit           847      1100   FN rate = 0.4350
#
#   --- Advanced  (X_train: (14578, 687)) ---
#      Test Accuracy : 0.5435
#      Test F1-Score : 0.5667
#      Confusion Matrix:
#                        Pred:Miss  Pred:Hit
#         True:Miss          893       805   FP rate = 0.4741
#         True:Hit           859      1088   FN rate = 0.4412
#
#   >> Δ (Advanced − Baseline):  Acc -0.0060  |  F1 -0.0060
#
#   Wrote results/perceptron/metrics.json

# %% [markdown]
# ## 2. Plots

# %%
from IPython.display import Image, display

for name in ["confusion_matrix.png", "roc_curve.png"]:
    display(Image(filename=f"results/perceptron/{name}"))

# %% [markdown]
# ## 3. Metrics summary

# %%
from src import load_metrics

metrics = load_metrics("perceptron")
for ds, vals in metrics["datasets"].items():
    print(f"{ds:>9}:  accuracy={vals['accuracy']:.4f}  F1={vals['f1']:.4f}")
# Out:
#  Baseline:  accuracy=0.5495  F1=0.5726
#  Advanced:  accuracy=0.5435  F1=0.5667
