# %% [markdown]
# # PCA + KNN (Improved)
#
# Drops the outlier-heavy nutrition columns before PCA, then KNN (k=5).

# %% [markdown]
# ## 1. Run the training script
#
# `train_pca_knn_improved.py` trains the model on the Baseline and Advanced matrices and writes its metrics and plots to `results/pca_knn_improved/`.

# %%
import os, sys
from pathlib import Path

if Path.cwd().name == "notebooks":
    os.chdir(Path.cwd().parent)
if str(Path.cwd()) not in sys.path:
    sys.path.insert(0, str(Path.cwd()))

# %%
# %run train_pca_knn_improved.py
# Out:
# ========================================================================
#   TRAIN — PCA(0.90) + KNN (Improved)   (random_state = 42)
# ========================================================================
#   Dropping ['calories', 'protein', 'fat', 'sodium'] before PCA.
#
#   --- Baseline  (X_train: (14578, 678)) ---
#      Test Accuracy : 0.5599
#      Test F1-Score : 0.5819
#      Confusion Matrix:
#                        Pred:Miss  Pred:Hit
#         True:Miss          925       773   FP rate = 0.4552
#         True:Hit           831      1116   FN rate = 0.4268
#      Columns before drop : 678
#      Columns after drop  : 674
#      PCA components retained for 90% variance : 203  (was 1 in train_pca_knn.py)
#
#   --- Advanced  (X_train: (14578, 687)) ---
#      Test Accuracy : 0.5726
#      Test F1-Score : 0.6023
#      Confusion Matrix:
#                        Pred:Miss  Pred:Hit
#         True:Miss          907       791   FP rate = 0.4658
#         True:Hit           767      1180   FN rate = 0.3939
#      Columns before drop : 687
#      Columns after drop  : 683
#      PCA components retained for 90% variance : 178  (was 1 in train_pca_knn.py)
#
#   >> Δ (Advanced − Baseline):  Acc +0.0126  |  F1 +0.0205
#
#   Wrote results/pca_knn_improved/metrics.json

# %% [markdown]
# ## 2. Plots

# %%
from IPython.display import Image, display

for name in ["confusion_matrix.png", "roc_curve.png"]:
    display(Image(filename=f"results/pca_knn_improved/{name}"))

# %% [markdown]
# ## 3. Metrics summary

# %%
from src import load_metrics

metrics = load_metrics("pca_knn_improved")
for ds, vals in metrics["datasets"].items():
    print(f"{ds:>9}:  accuracy={vals['accuracy']:.4f}  F1={vals['f1']:.4f}")
# Out:
#  Baseline:  accuracy=0.5599  F1=0.5819
#  Advanced:  accuracy=0.5726  F1=0.6023
