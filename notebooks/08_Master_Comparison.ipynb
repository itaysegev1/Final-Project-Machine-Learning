# %% [markdown]
# # Model Comparison
#
# Reads every `results/<model>/metrics.json` and prints the side-by-side Baseline-vs-Advanced table. Run the model notebooks (or the `train_*.py` scripts) first so the results exist.

# %% [markdown]
# ## 1. Summary table

# %%
import os, sys
from pathlib import Path

if Path.cwd().name == "notebooks":
    os.chdir(Path.cwd().parent)
if str(Path.cwd()) not in sys.path:
    sys.path.insert(0, str(Path.cwd()))

# %%
# %run evaluate_all_results.py
# Out:
# ========================================================================
#   AGGREGATOR — model results summary
# ========================================================================
#   Reading metrics from: /Users/itaysegev/Desktop/Final-Project-Machine-Learning/results/<model_slug>/metrics.json
#   Found 8 model result file(s).
#
# ========================================================================
#   SUMMARY — Feature Engineering A/B comparison
# ========================================================================
#                                                Model Acc (Baseline) Acc (Advanced)   Δ Acc F1 (Baseline) F1 (Advanced)    Δ F1
#                                           Perceptron         0.5495         0.5435 -0.0060        0.5726        0.5667 -0.0060
#                                  Logistic Regression         0.5984         0.6014 +0.0030        0.6428        0.6408 -0.0020
#                                     AdaBoost (n=100)         0.5948         0.5967 +0.0019        0.6621        0.6518 -0.0103
#                                      PCA(0.90) + KNN         0.5147         0.5092 -0.0055        0.5565        0.5508 -0.0057
#                           PCA(0.90) + KNN (Improved)         0.5599         0.5726 +0.0126        0.5819        0.6023 +0.0205
#                                        Random Forest         0.6041         0.6239 +0.0198        0.6565        0.6753 +0.0188
#                       MLP (128, 64) + early stopping         0.5973         0.6126 +0.0154        0.6668        0.6632 -0.0037
# MLP (128, 64) — no early stopping (overfit baseline)         0.5641         0.5728 +0.0088        0.5828        0.5936 +0.0107
#
#   Reading the table: positive Δ means the engineered culinary features improved that metric over the baseline.
#
# ========================================================================
#   CROSS-MODEL NOTE — Linear baseline vs Non-linear models
# ========================================================================
#
#   Reference (calibrated linear): LR Advanced   Acc 0.6014   F1 0.6408
#   RandomForest:          Acc 0.6239 (+0.0225)   F1 0.6753 (+0.0346)   →  BREAKS the linear ceiling on both metrics.
#   MLP (128,64):          Acc 0.6126 (+0.0112)   F1 0.6632 (+0.0224)   →  BREAKS the linear ceiling on both metrics.

# %% [markdown]
# ## 2. Headline plots

# %%
from IPython.display import Image, display

gallery = [
    "logistic_regression/confusion_matrix.png",
    "logistic_regression/roc_curve.png",
    "random_forest/feature_importance.png",
    "mlp/loss_curve.png",
]
for rel in gallery:
    path = Path("results") / rel
    if path.exists():
        display(Image(filename=str(path)))
    else:
        print(f"[missing] {rel}")
